# %%
import pandas as pd
from os.path import join

# %%
date_export = "2024-07-28"
date_export2 = date_export.replace("-", "")
data_file = join("extractions", f"rbx_bib_qual_{date_export2}.csv.gz")

rbx_bib_qual = pd.read_csv(data_file)
# Out:
# /tmp/ipykernel_4987/1902293508.py:5: DtypeWarning: Columns (0,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   rbx_bib_qual = pd.read_csv(data_file)

# %%
rbx_bib_qual
# Out:
#        record_id type_notice   niveau_bib  \
# 0              1       texte  monographie
# 1              2       texte  monographie
# 2              3       texte  monographie
# 3              4       texte  monographie
# 4              6       texte  monographie
# ...          ...         ...          ...
# 237616    368068       texte  monographie
# 237617    368070       texte  monographie
# 237618    368071       texte  monographie
# 237619    368072       texte  monographie
# 237620    368073       texte  monographie
#
#                              rbx_vdg_action rbx_support  \
# 0       notice bibliographique et autorités       Livre
# 1       notice bibliographique et autorités       Livre
# 2       notice bibliographique et autorités       Livre
# 3       notice bibliographique et autorités       Livre
# 4       notice bibliographique et autorités       Livre
# ...                                     ...         ...
# 237616  notice bibliographique et autorités       Livre
# ...

# %%
len(rbx_bib_qual[~rbx_bib_qual['publication_date_B214'].isna()])
# Out:
# 35990

# %%
rbx_bib_qual['type_notice'].value_counts()
# Out:
# type_notice
# texte                     172373
# son – musique              44602
# video                      13514
# partition                   3080
# son - non musical           1725
# multimedia                  1001
# s                            399
#                              383
# carte                        301
# image, dessin                130
# ressource électronique        99
# objet                          9
# partition manuscrite           4
# |                              1
# Name: count, dtype: int64

# %%
rbx_bib_qual.columns
# Out:
# Index(['record_id', 'type_notice', 'niveau_bib', 'rbx_vdg_action',
#        'rbx_support', 'title', 'publication_date_B100',
#        'publication_date_B210', 'publication_date_B214',
#        'publication_date_B219', 'rbx_public', 'agence_cat', 'nb_items'],
#       dtype='object')
